# %%
import sys
import platform

print("=== Colab Connection Test ===")
print(f"Python version: {sys.version}")
print(f"Platform: {platform.platform()}")

try:
    import google.colab
    print("\n✅ google.colab module found! You are running in a Google Colab environment.")
except ImportError:
    print("\n❌ google.colab module NOT found. You might not be connected to the Colab backend.")

try:
    import torch
    if torch.cuda.is_available():
        print(f"\n✅ GPU is available: {torch.cuda.get_device_name(0)}")
    else:
        print("\nℹ️ CUDA (GPU) is not available. You might be on a CPU-only runtime.")
except ImportError:
    print("\nℹ️ PyTorch not installed to verify GPU, skipping GPU check.")
# Out:
# === Colab Connection Test ===
# Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# Platform: Linux-6.6.113+-x86_64-with-glibc2.35
#
# ✅ google.colab module found! You are running in a Google Colab environment.
#
# ℹ️ CUDA (GPU) is not available. You might be on a CPU-only runtime.
# Linux 759b0d5a43b2 6.6.113+ #1 SMP Mon Feb  2 12:27:57 UTC 2026 x86_64 x86_64 x86_64 GNU/Linux
# /bin/bash: line 1: nvidia-smi: command not found

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Out:
# Linux 759b0d5a43b2 6.6.113+ #1 SMP Mon Feb  2 12:27:57 UTC 2026 x86_64 x86_64 x86_64 GNU/Linux
# /bin/bash: line 1: nvidia-smi: command not found
